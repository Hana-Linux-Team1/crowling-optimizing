# %%
import requests
from bs4 import BeautifulSoup
import os
from PIL import Image

p_num = 780003799
url = 'https://www.daangn.com/articles/780003788'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# 페이지 요청
response = requests.get(url, headers=headers)

# 요청이 성공적인지 확인
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # 제목 추출
    title_tag = soup.find('h1', class_='hide')
    title = title_tag.get_text(strip=True) if title_tag else '제목 없음'

    # 가격 추출
    price_tag = soup.find('p', id='article-price')
    price = price_tag.get_text(strip=True) if price_tag else '가격 없음'
    
    # 설명 추출
    description_tag = soup.find('div', id='article-detail')
    description = ''
    if description_tag:
        for br in description_tag.find_all('br'):
            br.replace_with('\n')
        description = description_tag.get_text(strip=True)
    else:
        description ='설명 없음'
    
    # 이미지 추출
    
    img_url = soup.find('div', class_='image-wrap').find('img')['data-lazy']
    # os.system("curl " + img_url + " > test.jpg")
    # img = Image.open("test.jpg")
#     if img_tag:
#         img_link = img_tag.find('img')['src']
#         os.system("curl " + url + " > test.jpg")
        
#         # 저장 된 이미지 확인
#         img = Image.open("test.jpg")
#     else:
#         img_link = '링크 없음'
        
    # 위치 추출
    location_tag = soup.find('div', id='region-name')
    location = location_tag.get_text(strip=True) if location_tag else '위치 없음'

    # 추출된 데이터 출력
    print('제목:', title)
    print('가격:', price)
    print('설명:', description)
    print('위치:', location)
    
    print('이미지 url: ',img_url)

else:
    print('페이지 요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 제목: 이동식 행거
# 가격: 가격 없음
# 설명: 바퀴가 있어 이동하는데 여자인 저 혼자도 충분히 옮기는데 무리없었어요. 튼튼하고 편하게 잘 썼는데 이사때문에 나눔하려구요.
# 위치: 강동구 천호동
# 이미지 url:  https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside

# %%
https://dnvefa72aowie.cloudfront.net/origin/article/202406/c52b052f7b5459cf90963e54dd2f6a42e7ec482268fc8d7f7d42f606ebb7cf2f.jpg?f=webp&q=95&s=1440x1440&t=inside

# %%
import requests
from bs4 import BeautifulSoup
def karrot_crawling(p_num):
    url = 'https://www.daangn.com/articles/'+str(p_num)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    # file = open('./crawling.txt','w')
    # 페이지 요청
    response = requests.get(url, headers=headers)

    # 요청이 성공적인지 확인
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # 제목 추출
        title_tag = soup.find('h1', class_='hide')
        title = title_tag.get_text(strip=True) if title_tag else '제목 없음'

        # 가격 추출
        price_tag = soup.find('p', id='article-price')
        price = price_tag.get_text(strip=True) if price_tag else '가격 없음'

        # 설명 추출
        description_tag = soup.find('div', id='article-detail')
        description = ''
        if description_tag:
            for br in description_tag.find_all('br'):
                br.replace_with('\n')
            description = description_tag.get_text(strip=True)
        else:
            description ='설명 없음'
        
        # 이미지 url 추출
        try:
            img_url_tag = soup.find('div', class_='image-wrap').find('img')['data-lazy']
        except:
            print('이미지 없음')
        # img_url = img_url_tag.get_text(strip=True) if img_url_tag else 'url 없음'
        
        # 위치 추출
        location_tag = soup.find('div', id='region-name')
        location = location_tag.get_text(strip=True) if location_tag else '위치 없음'

        # 추출된 데이터 출력
        print('제목:', title)
        print('가격:', price)
        print('설명:', description)
        print('위치:', location)
        print('이미지 url', img_url)
        print('============================================================\n')
        
        # file.write('제목:'+ title+'\n')
        # file.write('가격:'+ price+'\n')
        # file.write('설명:'+ description+'\n')
        # file.write('위치:'+ location+'\n')
        # file.write('이미지 url'+img_url+'\n')
        # file.write('============================================================\n')

    else:
        print('페이지 요청에 실패했습니다. 상태 코드:', response.status_code)
    # file.close()

# %%
from threading import Thread

# %%
p_num = 780003799


for i in range(10):
    karrot_crawling(p_num+i)
# Out:
# 제목: 추억의 PSP 판매합니다 (모든 기능 정상작동)
# 가격: 20,000원
# 설명: 추억의 PSP (플레이스테이션폴테이블) 정품메모리칩 8GB 탑재 및 다수의 게임들 포함중입니다Ex) 피파, 에이스컴뱃, 어쌔신 크리드2만원(치킨한마리 값에) 추억의 킬링타임용 게임 여러개까지 들어있으니 추억 찾고 싶으신 분들 구매하시면 되겠습니다!충전 ok, 연식에 따른생활기스, 기능 및 조이스틱 정상 확인 완료.
# 위치: 은평구 불광제2동
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 제목: 신세계 상품권 만원권X2   1.5만원에 드려요.
# 가격: 15,000원
# 설명: 근처분들 오시면 좋겠네요.오늘은 집에 있습니다.광주시 능평동  ***-****-****  ***-****-**** 문자 먼저 주세요
# 위치: 광주시 오포읍
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 제목: 스타벅스 프리퀀시 1개
# 가격: 1,500원
# 설명: 스타벅스 프리퀀시 1개
# 위치: 강남구 역삼동
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 제목: 엔시티 랜포
# 가격: 500원
# 설명: 한판당 500원 여러번 가능번호36번까지하자없음배송 반택 끼택3,16,25,31🙅‍♀️
# 위치: 청주시 흥덕구 오송읍
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 이미지 없음
# 제목: 랩스휘트니스죽전점 회원권 판매합니다.
# 가격: 250,000원
# 설명: 랩스휘트니스죽전점 회원권 양도합니다.6월4일기준 25.4.27일 만료로 약 10개월 20일정도 남았고 현재 한달 정지했습니다.(정지후 만료일 25.5.26)정지는 3개월에 1회씩 한달 정지 가능합니다.개인락커는 안했고 운동복은 신청하여 사용 가능합니다.
# 위치: 광주시 오포읍
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 제목: 인견100     66
# 가격: 10,000원
# 설명: 상태좋아요    예쁩니다    M사이즈    저렴해요
# 위치: 도봉구 방학제1동
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 이미지 없음
# 제목: 제목 없음
# 가격: 가격 없음
# 설명: 설명 없음
# 위치: 위치 없음
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 제목: 헬리녹스 15주년 토르박스 판매해요
# 가격: 165,000원
# 설명: 헬리녹스 15주년 토르박스 판매해요미사용품 정가에 판매합니다.무지성소비하였으나 평일에 판매 안되면 주말에지인판매할예정입니다.
# 위치: 연수구 송도동
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 제목: 스커트 S
# 가격: 7,000원
# 설명: 사이즈 74. S총장 85. 뒤트임 35소재표기는 없으나 안감있는모직느낌 소재입니다상태좋습니다
# 위치: 진주시 망경동
# 이미지 url https://dnvefa72aowie.cloudfront.net/origin/article/202406/812149e509474f644e62a455b495f2ccd4e990634dcc5b34e1dc49664697cc98_0.webp?f=webp&q=95&s=1440x1440&t=inside
# ============================================================
#
# 페이지 요청에 실패했습니다. 상태 코드: 404
